# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('../Utilities/Model/pipe.pkl','rb'))

# %%
# User Input : Pclass/gender/age/SibSp/Parch/Fare/Embarked
test_input =np.array([2, 'male', 31.0, 0, 0, 11, 'C'], dtype=object).reshape(1,7)
test_input
# Out:
# array([[2, 'male', 31.0, 0, 0, 11, 'C']], dtype=object)

# %%
pipe.predict(test_input)
# Out:
# /Users/arbazkhan/kael/kael_env/lib/python3.11/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# /Users/arbazkhan/kael/kael_env/lib/python3.11/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([1])
