# %%
import requests
import pandas as pd

url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=1&sort_by=popularity.desc"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4ZjcyOGJjNGFkNGFmZTRhNzBiMmQ4YWY1YmQyZDZkOCIsIm5iZiI6MTc4Mzc1Nzg0My4xMDQsInN1YiI6IjZhNTFmYzEzY2IzM2RmMjdkMjA1MzMxMSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.pO9ssnu1XmDG2Sxg4-Allxt1InmrOkDxV_32anOeXAk"
}

response = requests.get(url, headers=headers)


#response.json()
# Converting into Dataframe
df = pd.DataFrame(response.json()['results'])
df
# Out:
#     adult                     backdrop_path                genre_ids       id  \
# 0   False  /r013C8Me2bZ0pUi0OWJRh0h7MzT.jpg                 [27, 53]  1339713
# 1   False  /qjTqY5coNiz6sVtPng40IzltsoN.jpg      [16, 10751, 35, 12]  1084244
# 2   False  /s6ly8laenkHWlIBRkLSfIuEMLC6.jpg                [878, 53]  1275779
# 3   False  /xWBiXclrRmTggQHMRsIn84YHavs.jpg                 [35, 27]  1273221
# 4   False  /mCpwRayjXMFzKHbjbzc5JRKfq1O.jpg          [27, 9648, 878]  1083381
# 5   False  /Af907x5h9W1wVis8XrSd7ynTWuy.jpg                 [35, 18]  1314481
# 6   False  /1AVF2fAevpfi2HP6AEpptG1kg8R.jpg             [28, 80, 53]  1280738
# 7   False  /1x9e0qWonw634NhIsRdvnneeqvN.jpg                  [10749]  1523145
# 8   False  /3pDfu71mrzSuFYyIfnKEjt8z4BC.jpg                 [27, 53]  1368314
# 9   False  /qJ2KSHJhlFvASBMLbGuP7OFMaFg.jpg             [53, 28, 80]  1413976
# 10  False  /c6BPbkO5Npt1OdwttAxCFo06wtH.jpg      [10751, 14, 35, 12]  1108427
# ...

# %%
# Extracting required Info

df = df.head(10)[['id', 'title', 'overview', 'popularity', 'release_date', 'vote_average', 'vote_count']]
df
# Out:
#         id                      title  \
# 0  1339713                  Obsession
# 1  1084244                Toy Story 5
# 2  1275779             Disclosure Day
# 3  1273221                Scary Movie
# 4  1083381                  Backrooms
# 5  1314481    The Devil Wears Prada 2
# 6  1280738                The Furious
# 7  1523145  Your Heart Will Be Broken
# 8  1368314                  Passenger
# 9  1413976          Citizen Vigilante
#
#                                             overview  popularity release_date  \
# 0  After breaking the mysterious "One Wish Willow...    706.7361   2026-05-13
# 1  When Bonnie receives a Lilypad tablet as a gif...    679.9618   2026-06-17
# 2  A cybersecurity expert becomes a whistleblower...    516.3681   2026-06-10
# 3  Twenty-six years after outrunning a suspicious...    397.9695   2026-06-03
# 4  A strange doorway appears in the basement of a...    387.1929   2026-05-27
# ...
